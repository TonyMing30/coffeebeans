# %%
import cv2
import pandas as pd
import numpy as np
import os
from sklearn import preprocessing
import time
from collections import Counter
from skimage.feature import hog
from skimage import data, exposure
# from skimage.feature import greycomatrix, greycoprops
import math
from skimage.feature import graycomatrix, graycoprops
from scipy.stats import skew,kurtosis
# from mahotas.features import surf
from skimage import measure
from skimage import feature, color
# import mahotas
import mimetypes
import matplotlib.pyplot as plt
from skimage.filters import gabor
from skimage.color import rgb2gray
from PIL import Image

# %%
root_path = '/Users/tony/Desktop/CoffeeBeansT'
# root_path = 'D:\\ProjectMango\\output\\augmentation-enhancement'
current_dir = os.getcwd()
os.chdir(root_path)
print(current_dir)
# Out:
# /Users/tony/Downloads

# %%
os.listdir()
# Out:
# ['.DS_Store', 'Bad', 'Normal']

# %%
from os import walk

label = []
path = []
names = []

for folder_name in os.listdir():
    current_dir = os.path.join(root_path,folder_name)
    for root,dirs,files in walk(current_dir):
      for file in files:
        file_mimetype = mimetypes.guess_type(file)[0]
        if file_mimetype == 'image/jpeg':
          path.append(os.path.join(root,file))
          label.append(folder_name)
          names.append(file)

# %%
len(path), len(label)
# Out:
# (5400, 5400)

# %%
df = pd.DataFrame(np.array([path,names,label]).T,columns=['path','filename','label'])
df
# Out:
#                                                    path  \
# 0     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 1     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 2     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 3     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 4     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# ...                                                 ...
# 5395  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5396  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5397  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5398  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5399  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
#
#                            filename   label
# 0       HoneyMedium_Bad_4_BS_10.JPG     Bad
# 1        HoneyMedium_Bad_1_FS_8.JPG     Bad
# 2        HoneyMedium_Bad_6_BS_9.JPG     Bad
# 3        HoneyMedium_Bad_7_BS_9.JPG     Bad
# 4        HoneyMedium_Bad_2_BS_3.JPG     Bad
# ...                             ...     ...
# 5395  DryLight_Finished_17_FS_6.JPG  Normal
# 5396   DryLight_Finished_6_FS_6.JPG  Normal
# 5397  DryLight_Finished_16_FS_6.JPG  Normal
# 5398   DryLight_Finished_7_FS_6.JPG  Normal
# 5399  DryLight_Finished_6_FS_10.JPG  Normal
#
# [5400 rows x 3 columns]

# %%
df.dtypes
# Out:
# path        object
# filename    object
# label       object
# dtype: object

# %%
def find_static_data(img,hsv=False):
  #b,g,r
  #h,s,v
  #计算图像在每个颜色通道的均值和标准差
  mean = img.mean(axis=(0,1))
  sd = img.std(axis=(0,1))

  if hsv:
    #如果hsv为Ture，则先将图像从RGB转换为HSV颜色空间
    #h,s,v = cv2.split(img)
    img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(img_hsv)
    
    flatted_H = h.flatten()
    flatted_S = s.flatten()
    flatted_V = v.flatten()

    s_h = skew(flatted_H)
    s_s = skew(flatted_S)
    s_v = skew(flatted_V)

    k_h = kurtosis(flatted_H)
    k_s = kurtosis(flatted_S)
    k_v = kurtosis(flatted_V)

    payload = {
      'mean' : mean,
      'std' : sd,
      'skew' : [s_h,s_s,s_v],
      'kurtosis' : [k_h,k_s,k_v]
    }
    
  else:
    b, g, r = cv2.split(img)

    flatted_B = b.flatten()
    flatted_G = g.flatten()
    flatted_R = r.flatten()

    s_b = skew(flatted_B)
    s_g = skew(flatted_G)
    s_r = skew(flatted_R)

    k_b = kurtosis(flatted_B)
    k_g = kurtosis(flatted_G)
    k_r = kurtosis(flatted_R)

    payload = {
      'mean' : mean,
      'std' : sd,
      'skew' : [s_b,s_g,s_r],
      'kurtosis' : [k_b,k_g,k_r]
    }

  return payload

# %%
def get_pixel(img, center, x, y):
    """
    比较图像中的一个像素与中心像素的值。
    
    参数:
    - img: 输入图像
    - center: 中心像素的灰度值
    - x, y: 要比较的像素的坐标
    
    返回:
    - 如果指定像素的值大于等于中心像素的值，则返回1，否则返回0。
    - 如果指定像素位于图像边界外，则视为0。
    """
    th = 0   # 阈值，可以调整
    try:
        # 检查像素是否在图像边界内
        if img[x, y] >= center - th:
            return 1
        else:
            return 0
    except IndexError:
        # 如果像素位于图像边界之外，则返回0
        return 0


# Function for calculating LBP
def lbp_calculated_pixel(img, x, y):
    """
    计算并返回图像中指定像素位置的局部二值模式(LBP)值
    """
    center = img[x][y]
   
    val_ar = []
      
    # top_left
    val_ar.append(get_pixel(img, center, x-1, y-1))
      
    # top
    val_ar.append(get_pixel(img, center, x-1, y))
      
    # top_right
    val_ar.append(get_pixel(img, center, x-1, y + 1))
      
    # right
    val_ar.append(get_pixel(img, center, x, y + 1))
      
    # bottom_right
    val_ar.append(get_pixel(img, center, x + 1, y + 1))
      
    # bottom
    val_ar.append(get_pixel(img, center, x + 1, y))
      
    # bottom_left
    val_ar.append(get_pixel(img, center, x + 1, y-1))
      
    # left
    val_ar.append(get_pixel(img, center, x, y-1))
       
    # Now, we need to convert binary
    # values to decimal
    #将二进制值转换为十进制
    power_val = [1, 2, 4, 8, 16, 32, 64, 128]
   
    val = 0
      
    for i in range(len(val_ar)):
        val += val_ar[i] * power_val[i]
          
    return val

# %%
def get_pixel(img, center, x, y):
      
    new_value = 0
      
    try:
        # If local neighbourhood pixel 
        # value is greater than or equal
        # to center pixel values then 
        # set it to 1
        if img[x][y] >= center:
            new_value = 1
              
    except:
        # Exception is required when 
        # neighbourhood value of a center
        # pixel value is null i.e. values
        # present at boundaries.
        pass
      
    return new_value

# %%
def compute_haralick_features(image, distances, angles):
    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM matrix
    glcm = graycomatrix(gray_image, distances, angles, levels=256, symmetric=True, normed=True)

    # Calculate the Haralick texture features
    features = []
    for prop in ['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation']:
        feature = np.mean(graycoprops(glcm, prop))
        features.append(feature)
        
    payload = {
      'Contrast' : features[0],
      'Dissimilarity' : features[1],
      'Homogeneity' : features[2],
      'Energy' : features[3],
      'Correlation' : features[4]
    }
    
    return payload

# %%
def extract_hog_features(image):
    # Convert the image to grayscale
    gray_image = color.rgb2gray(image)
    
    # Extract HOG features
    hog_features = feature.hog(gray_image)

    return hog_features

# %%
def extract_contour_features(image_path):
    # Load the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    threshold_value = 128  # Adjust this value based on your image characteristics

    # Apply thresholding to create a binary image
    _, binary_image = cv2.threshold(image, threshold_value, 255, cv2.THRESH_BINARY)

    # Find contours in the binary image
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Initialize a list to store contour-based features
    contour_features_list = []
    
    # Loop through each contour
    for contour in contours:
        # Calculate area of the contour
        area = cv2.contourArea(contour)
        
        # Calculate perimeter of the contour
        perimeter = cv2.arcLength(contour, True)
        
        # Calculate compactness (perimeter^2 / area)
        compactness = (perimeter ** 2) / area if area != 0 else 0.0
        
        # Calculate bounding box dimensions
        x, y, w, h = cv2.boundingRect(contour)
        
        # Calculate aspect ratio of the bounding box
        aspect_ratio = float(w) / h
        
        # Calculate extent (area of contour / area of bounding box)
        extent = area / (w * h)
        
        # Create a dictionary to store the features
        features_dict = {
            "Area": area,
            "Perimeter": perimeter,
            "Compactness": compactness,
            "Aspect Ratio": aspect_ratio,
            "Extent": extent
        }
        
        # Add the dictionary to the list
        contour_features_list.append(features_dict)
    
    return contour_features_list

# %%
for row,path in enumerate(df['path']):
  start = time.time()
  image = cv2.imread(path)
  image_resize = cv2.resize(image,(256,256),interpolation = cv2.INTER_AREA)
  print(path)

  # # # Shape Feature Extraction Contour
  contour = extract_contour_features(path)
  df.loc[row,'contourArea'] = contour[0]['Area']
  df.loc[row,'contourPerimeter'] = contour[0]['Perimeter']
  df.loc[row,'contourCompactness'] = contour[0]['Compactness']
  df.loc[row,'contourAspectRatio'] = contour[0]['Aspect Ratio']
  df.loc[row,'contourExtent'] = contour[0]['Extent']


  # # # Texture Feature Extraction LBP
  height, width, _ = image_resize.shape
  img_gray = cv2.cvtColor(image_resize,cv2.COLOR_BGR2GRAY)
  img_lbp = np.zeros((height, width),np.uint8)
  for i in range(0, height):
    for j in range(0, width):
        img_lbp[i, j] = lbp_calculated_pixel(img_gray, i, j)
  vector_lbp = img_lbp.flatten()
  counted = Counter(vector_lbp)
  for key,value in counted.items():
    df.loc[row, f"lbp_{key}"] = value

  # # # Texture Feature Extraction Haralick
  distances = [1]  # Distance between pixels in the GLCM
  angles = [0, np.pi/4, np.pi/2, 3*np.pi/4]  # Angles for GLCM computation

  haralick_features = compute_haralick_features(image_resize, distances, angles)
  print(haralick_features)
  df.loc[row,'Contrast'] = haralick_features['Contrast']
  df.loc[row,'Dissimilarity'] = haralick_features['Dissimilarity']
  df.loc[row,'Homogeneity'] = haralick_features['Homogeneity']
  df.loc[row,'Energy'] = haralick_features['Energy']
  df.loc[row,'Correlation'] = haralick_features['Correlation']


  # # # # Color Feature Extraction RGB
  # payload_rgb = find_static_data(image_resize)
  # #Average
  # df.loc[row,'R_mean'] = payload_rgb['mean'][2]
  # df.loc[row,'G_mean'] = payload_rgb['mean'][1]
  # df.loc[row,'B_mean'] = payload_rgb['mean'][0]
  # #Standard deviation
  # df.loc[row,'R_STD'] = payload_rgb['std'][2]
  # df.loc[row,'G_STD'] = payload_rgb['std'][1]
  # df.loc[row,'B_STD'] = payload_rgb['std'][0]
  # # Skewness
  # df.loc[row,'R_skewness'] = payload_rgb['skew'][2]
  # df.loc[row,'G_skewness'] = payload_rgb['skew'][1]
  # df.loc[row,'B_skewness'] = payload_rgb['skew'][0]
  # # Kurtosis
  # df.loc[row,'R_kurtosis'] = payload_rgb['kurtosis'][2]
  # df.loc[row,'G_kurtosis'] = payload_rgb['kurtosis'][1]
  # df.loc[row,'B_kurtosis'] = payload_rgb['kurtosis'][0]



  # # # # Color Feature Extraction HSV
  # hsv = cv2.cvtColor(image_resize,cv2.COLOR_RGB2HSV)
  # payload_hsv = find_static_data(hsv,hsv = True)

  # #Average
  # df.loc[row,'H_mean'] = payload_hsv['mean'][0]
  # df.loc[row,'S_mean'] = payload_hsv['mean'][1]
  # df.loc[row,'V_mean'] = payload_hsv['mean'][2]
  # #Standard deviation
  # df.loc[row,'H_STD'] = payload_hsv['std'][0]
  # df.loc[row,'S_STD'] = payload_hsv['std'][1]
  # df.loc[row,'V_STD'] = payload_hsv['std'][2]
  # # Skewness
  # df.loc[row,'H_skewness'] = payload_hsv['skew'][0]
  # df.loc[row,'S_skewness'] = payload_hsv['skew'][1]
  # df.loc[row,'V_skewness'] = payload_hsv['skew'][2]
  # # Kurtosis
  # df.loc[row,'H_kurtosis'] = payload_hsv['kurtosis'][0]
  # df.loc[row,'S_kurtosis'] = payload_hsv['kurtosis'][1]
  # df.loc[row,'V_kurtosis'] = payload_hsv['kurtosis'][2]
    
  print('finished task at '+ str(time.time() - start))
# Out:
# /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedium_BadT/HoneyMedium_Bad_4_BS_10.JPG
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# /var/folders/jf/xh02rcr94fldxv1s3g2krtlr0000gn/T/ipykernel_75410/2868987910.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[row, f"lbp_{key}"] = value
# ...
# finished task at 0.16701579093933105
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_3_FS_9.JPG
# {'Contrast': 43.65817721849652, 'Dissimilarity': 2.332352535683333, 'Homogeneity': 0.5696080774357329, 'Energy': 0.10050627141821178, 'Correlation': 0.9953592589874671}
# finished task at 0.15996193885803223
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_17_BS_10.JPG
# {'Contrast': 27.72132304882679, 'Dissimilarity': 1.528143832900767, 'Homogeneity': 0.6983874321585911, 'Energy': 0.24348161731434892, 'Correlation': 0.9965682728105905}
# finished task at 0.15741324424743652
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_20_BS_8.JPG
# {'Contrast': 21.70226697664309, 'Dissimilarity': 1.3155590397923564, 'Homogeneity': 0.7024513687499099, 'Energy': 0.1953709944413518, 'Correlation': 0.9973299238930149}
# finished task at 0.15985822677612305
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_3_BS_10.JPG
# {'Contrast': 24.560834024172877, 'Dissimilarity': 1.54571090445979, 'Homogeneity': 0.6385397224056868, 'Energy': 0.18623696600631184, 'Correlation': 0.996674927485906}
# finished task at 0.15982508659362793
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_17_FS_1.JPG
# {'Contrast': 34.17562974577012, 'Dissimilarity': 2.0026573913878747, 'Homogeneity': 0.6407166080332684, 'Energy': 0.14643550957186582, 'Correlation': 0.9957849844142362}
# finished task at 0.15847086906433105
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_6_FS_1.JPG
# {'Contrast': 38.481127285778456, 'Dissimilarity': 2.02445995830925, 'Homogeneity': 0.6585598082128499, 'Energy': 0.13728604186567406, 'Correlation': 0.9958839737795573}
# finished task at 0.1565399169921875
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_16_FS_1.JPG
# {'Contrast': 39.49819132064475, 'Dissimilarity': 2.1939269451652605, 'Homogeneity': 0.6174483423524869, 'Energy': 0.11149650688436408, 'Correlation': 0.9963597409370288}
# finished task at 0.1587238311767578
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_7_FS_1.JPG
# {'Contrast': 36.05515944888904, 'Dissimilarity': 1.8843648927094874, 'Homogeneity': 0.6596845963987947, 'Energy': 0.1488267210944607, 'Correlation': 0.9959624312356711}
# finished task at 0.15877199172973633
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_18_FS_8.JPG
# {'Contrast': 48.9022881824281, 'Dissimilarity': 2.5326448661571623, 'Homogeneity': 0.608124730436261, 'Energy': 0.12030094745289688, 'Correlation': 0.9946106484882391}
# finished task at 0.16194415092468262
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_9_FS_8.JPG
# {'Contrast': 37.904421256246756, 'Dissimilarity': 2.0550187728277014, 'Homogeneity': 0.6252051316600091, 'Energy': 0.10695855845914522, 'Correlation': 0.9962061629186055}
# finished task at 0.15923094749450684
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_19_FS_8.JPG
# {'Contrast': 32.98102220299807, 'Dissimilarity': 1.962724973567802, 'Homogeneity': 0.6411742951128713, 'Energy': 0.13478139028884872, 'Correlation': 0.9965311119036497}
# finished task at 0.1617579460144043
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_8_FS_8.JPG
# {'Contrast': 47.48928184171828, 'Dissimilarity': 2.144111714845202, 'Homogeneity': 0.653609699388856, 'Energy': 0.14999411618974118, 'Correlation': 0.9950616302392026}
# finished task at 0.15799903869628906
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_19_FS_10.JPG
# {'Contrast': 34.53223641447921, 'Dissimilarity': 2.0215487582900247, 'Homogeneity': 0.6275497618023971, 'Energy': 0.12308457370133767, 'Correlation': 0.9961759176408043}
# finished task at 0.16080904006958008
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_19_FS_9.JPG
# {'Contrast': 37.25588555182984, 'Dissimilarity': 2.043494974889404, 'Homogeneity': 0.6341290069595547, 'Energy': 0.1179964294732975, 'Correlation': 0.9961789943127709}
# finished task at 0.15755796432495117
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_8_FS_9.JPG
# {'Contrast': 35.54344203551413, 'Dissimilarity': 1.9424020208573047, 'Homogeneity': 0.6589046999889526, 'Energy': 0.1347827268684491, 'Correlation': 0.9960008818729824}
# finished task at 0.16379785537719727
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_18_FS_9.JPG
# {'Contrast': 27.577840148620126, 'Dissimilarity': 1.593689491421527, 'Homogeneity': 0.6843185383798801, 'Energy': 0.13642265211951657, 'Correlation': 0.9965838116225538}
# finished task at 0.15773415565490723
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_9_FS_9.JPG
# {'Contrast': 40.81897710615983, 'Dissimilarity': 2.2782513636581476, 'Homogeneity': 0.595465539566677, 'Energy': 0.08692776689446649, 'Correlation': 0.9962528405838322}
# finished task at 0.15988802909851074
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_10_BS_1.JPG
# {'Contrast': 17.003022545414694, 'Dissimilarity': 1.3341903654843916, 'Homogeneity': 0.6918838529162995, 'Energy': 0.19726107225299744, 'Correlation': 0.9977949170720319}
# finished task at 0.15545105934143066
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_1_BS_1.JPG
# {'Contrast': 18.753793042338955, 'Dissimilarity': 1.3544321595059274, 'Homogeneity': 0.6680636358360934, 'Energy': 0.15543623766096915, 'Correlation': 0.9973180672989765}
# finished task at 0.16303420066833496
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_11_BS_1.JPG
# {'Contrast': 15.829645869376709, 'Dissimilarity': 1.118043420799666, 'Homogeneity': 0.7345004813065059, 'Energy': 0.22688561392095608, 'Correlation': 0.9973792922875824}
# finished task at 0.1659708023071289
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_20_BS_9.JPG
# {'Contrast': 18.072282220179247, 'Dissimilarity': 1.3341067287821675, 'Homogeneity': 0.6789906456352615, 'Energy': 0.15129619140702366, 'Correlation': 0.997515487734577}
# finished task at 0.1588296890258789
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_6_FS_4.JPG
# {'Contrast': 32.455403300412726, 'Dissimilarity': 1.8462614439157532, 'Homogeneity': 0.6588234929593858, 'Energy': 0.15872590810717924, 'Correlation': 0.9956062480037857}
# finished task at 0.15767192840576172
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_17_FS_4.JPG
# {'Contrast': 40.01451531562272, 'Dissimilarity': 2.178768036932852, 'Homogeneity': 0.6262031247471262, 'Energy': 0.14978044741712512, 'Correlation': 0.9957342421071785}
# finished task at 0.16041016578674316
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_7_FS_4.JPG
# {'Contrast': 36.11719361243188, 'Dissimilarity': 1.8993015757160283, 'Homogeneity': 0.6573661429965824, 'Energy': 0.14656055074666605, 'Correlation': 0.9958096365065865}
# finished task at 0.1574251651763916
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_12_FS_10.JPG
# {'Contrast': 37.693797697999806, 'Dissimilarity': 2.1955685914070964, 'Homogeneity': 0.6062737637732992, 'Energy': 0.10686452713864061, 'Correlation': 0.9959641982171339}
# finished task at 0.16065120697021484
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_16_FS_4.JPG
# {'Contrast': 28.764419273836303, 'Dissimilarity': 1.726682586024562, 'Homogeneity': 0.6726240107699901, 'Energy': 0.14921858583630582, 'Correlation': 0.9964199143639673}
# finished task at 0.15676498413085938
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_11_BS_5.JPG
# {'Contrast': 25.849005881150738, 'Dissimilarity': 1.6481815888119524, 'Homogeneity': 0.652240979069685, 'Energy': 0.17366740073416276, 'Correlation': 0.9969479083806972}
# finished task at 0.15911602973937988
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_1_BS_5.JPG
# {'Contrast': 20.293121695981753, 'Dissimilarity': 1.3673262987792834, 'Homogeneity': 0.655078886787758, 'Energy': 0.1451776908925041, 'Correlation': 0.9972102114214768}
# finished task at 0.1618497371673584
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_10_BS_5.JPG
# {'Contrast': 18.359736940118662, 'Dissimilarity': 1.4960727244328726, 'Homogeneity': 0.6439930034109251, 'Energy': 0.15936844597395333, 'Correlation': 0.9974022020738662}
# finished task at 0.15792274475097656
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_11_BS_10.JPG
# {'Contrast': 19.147951178632738, 'Dissimilarity': 1.3572298815359165, 'Homogeneity': 0.6741711496336402, 'Energy': 0.1434050344690084, 'Correlation': 0.9974801733410316}
# finished task at 0.15585112571716309
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_8_BS_10.JPG
# {'Contrast': 20.172541450403138, 'Dissimilarity': 1.2666312536043514, 'Homogeneity': 0.707239163405006, 'Energy': 0.15937484890244943, 'Correlation': 0.997590527972511}
# finished task at 0.15756607055664062
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_1_BS_4.JPG
# {'Contrast': 23.74080239571248, 'Dissimilarity': 1.5027976619569008, 'Homogeneity': 0.6305268441432536, 'Energy': 0.12339652836904197, 'Correlation': 0.996971161676846}
# finished task at 0.16058588027954102
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_10_BS_4.JPG
# {'Contrast': 16.940467308246337, 'Dissimilarity': 1.2046336745482216, 'Homogeneity': 0.7072258976159254, 'Energy': 0.19149324960654449, 'Correlation': 0.9975354151197341}
# finished task at 0.15749907493591309
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_11_BS_4.JPG
# {'Contrast': 19.46866083657673, 'Dissimilarity': 1.412877724312728, 'Homogeneity': 0.6641939355641797, 'Energy': 0.16942974004942854, 'Correlation': 0.9974894717070941}
# finished task at 0.1561589241027832
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_7_FS_5.JPG
# {'Contrast': 38.19697312932439, 'Dissimilarity': 1.9828714616973726, 'Homogeneity': 0.6485349758976549, 'Energy': 0.15992683367709187, 'Correlation': 0.9955869628080896}
# finished task at 0.16093063354492188
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_16_FS_5.JPG
# {'Contrast': 43.960203722725524, 'Dissimilarity': 2.3383557255622174, 'Homogeneity': 0.6143127486907971, 'Energy': 0.11084304662043414, 'Correlation': 0.9955443977538538}
# finished task at 0.15702581405639648
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_6_FS_5.JPG
# {'Contrast': 46.75659229623099, 'Dissimilarity': 2.3284675365243492, 'Homogeneity': 0.6199840669611374, 'Energy': 0.13748945581738203, 'Correlation': 0.995250960672238}
# finished task at 0.1678330898284912
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_17_FS_5.JPG
# {'Contrast': 38.09669260320465, 'Dissimilarity': 1.93330412281329, 'Homogeneity': 0.6902691904212381, 'Energy': 0.2188785467948891, 'Correlation': 0.9955016189391527}
# finished task at 0.157761812210083
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_16_FS_7.JPG
# {'Contrast': 28.01049594807226, 'Dissimilarity': 1.494637444132026, 'Homogeneity': 0.7145080209175235, 'Energy': 0.18588578127481056, 'Correlation': 0.9965994438146498}
# finished task at 0.1560359001159668
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_7_FS_7.JPG
# {'Contrast': 32.53988013924845, 'Dissimilarity': 1.7861309502354374, 'Homogeneity': 0.6936065869618213, 'Energy': 0.1667873208323847, 'Correlation': 0.9964399104797341}
# finished task at 0.1571049690246582
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_17_FS_7.JPG
# {'Contrast': 45.805934601474185, 'Dissimilarity': 2.19486127631194, 'Homogeneity': 0.6468150955511627, 'Energy': 0.15698165113871299, 'Correlation': 0.9950140140055663}
# finished task at 0.15857911109924316
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_6_FS_7.JPG
# {'Contrast': 36.538473123317175, 'Dissimilarity': 1.6742132833525138, 'Homogeneity': 0.7124789544048931, 'Energy': 0.19712845822902703, 'Correlation': 0.9954754630801862}
# finished task at 0.15827608108520508
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_10_BS_6.JPG
# {'Contrast': 19.011291375311885, 'Dissimilarity': 1.2895840692281484, 'Homogeneity': 0.7081804558545655, 'Energy': 0.2043883610261596, 'Correlation': 0.9974987008620524}
# finished task at 0.16434717178344727
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_1_BS_6.JPG
# {'Contrast': 20.160597591670918, 'Dissimilarity': 1.5114867028306036, 'Homogeneity': 0.6505960616904889, 'Energy': 0.15857241365681052, 'Correlation': 0.9973303825208167}
# finished task at 0.1625359058380127
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_11_BS_6.JPG
# {'Contrast': 22.494715433967016, 'Dissimilarity': 1.4277610774701646, 'Homogeneity': 0.6978502676993447, 'Energy': 0.2013440538058209, 'Correlation': 0.9971356408998275}
# finished task at 0.16120505332946777
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_5_BS_10.JPG
# {'Contrast': 23.315407295270507, 'Dissimilarity': 1.4701768850922345, 'Homogeneity': 0.6635229477847633, 'Energy': 0.15613033181839842, 'Correlation': 0.997054641891578}
# finished task at 0.16078472137451172
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_11_BS_7.JPG
# {'Contrast': 19.320153141219233, 'Dissimilarity': 1.2487289594146191, 'Homogeneity': 0.7198673486454927, 'Energy': 0.2187017092358297, 'Correlation': 0.9974589750045836}
# finished task at 0.15816330909729004
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_10_BS_7.JPG
# {'Contrast': 17.345673719242136, 'Dissimilarity': 1.121804324058027, 'Homogeneity': 0.7468087455526081, 'Energy': 0.25428355761043964, 'Correlation': 0.9974818836558415}
# finished task at 0.1555488109588623
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_1_BS_7.JPG
# {'Contrast': 28.604571303704713, 'Dissimilarity': 1.7159403384515142, 'Homogeneity': 0.608777256539246, 'Energy': 0.1318839381920034, 'Correlation': 0.9966444674397441}
# finished task at 0.1632981300354004
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_17_FS_6.JPG
# {'Contrast': 46.08282597137977, 'Dissimilarity': 2.2917111057044757, 'Homogeneity': 0.6321218085599886, 'Energy': 0.1533620248890562, 'Correlation': 0.9955349492522787}
# finished task at 0.15856409072875977
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_6_FS_6.JPG
# {'Contrast': 32.89240221609407, 'Dissimilarity': 1.7855881602027588, 'Homogeneity': 0.70140894107584, 'Energy': 0.22091129398464882, 'Correlation': 0.9960576664943661}
# finished task at 0.15917587280273438
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_16_FS_6.JPG
# {'Contrast': 32.55921984633228, 'Dissimilarity': 1.7919971735630007, 'Homogeneity': 0.6899711216502529, 'Energy': 0.16831856588251437, 'Correlation': 0.9964280138002077}
# finished task at 0.15932273864746094
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_7_FS_6.JPG
# {'Contrast': 41.27621721513245, 'Dissimilarity': 2.0761724306756437, 'Homogeneity': 0.6640130227456482, 'Energy': 0.18346953048185477, 'Correlation': 0.9954785724812217}
# finished task at 0.16076207160949707
# /Users/tony/Desktop/CoffeeBeansT/Normal/DryLight_NormalT/DryLight_Finished_6_FS_10.JPG
# {'Contrast': 40.98080176494495, 'Dissimilarity': 2.032475790561267, 'Homogeneity': 0.64490864596193, 'Energy': 0.13212527139650465, 'Correlation': 0.9957200361285443}
# finished task at 0.15654397010803223

# %%
df
# Out:
#                                                    path  \
# 0     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 1     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 2     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 3     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# 4     /Users/tony/Desktop/CoffeeBeansT/Bad/HoneyMedi...
# ...                                                 ...
# 5395  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5396  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5397  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5398  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
# 5399  /Users/tony/Desktop/CoffeeBeansT/Normal/DryLig...
#
#                            filename   label  contourArea  contourPerimeter  \
# 0       HoneyMedium_Bad_4_BS_10.JPG     Bad     159201.0            1596.0
# 1        HoneyMedium_Bad_1_FS_8.JPG     Bad     159201.0            1596.0
# 2        HoneyMedium_Bad_6_BS_9.JPG     Bad     159201.0            1596.0
# 3        HoneyMedium_Bad_7_BS_9.JPG     Bad     159201.0            1596.0
# 4        HoneyMedium_Bad_2_BS_3.JPG     Bad     159201.0            1596.0
# ...                             ...     ...          ...               ...
# 5395  DryLight_Finished_17_FS_6.JPG  Normal     249001.0            1996.0
# 5396   DryLight_Finished_6_FS_6.JPG  Normal     249001.0            1996.0
# 5397  DryLight_Finished_16_FS_6.JPG  Normal     249001.0            1996.0
# 5398   DryLight_Finished_7_FS_6.JPG  Normal     249001.0            1996.0
# 5399  DryLight_Finished_6_FS_10.JPG  Normal     248502.0            1994.0
#
#       contourCompactness  contourAspectRatio  contourExtent  lbp_120  lbp_232  \
# 0              16.000000            1.000000       0.995006    556.0     82.0
# 1              16.000000            1.000000       0.995006    772.0     70.0
# 2              16.000000            1.000000       0.995006    877.0     95.0
# 3              16.000000            1.000000       0.995006    698.0     75.0
# 4              16.000000            1.000000       0.995006    673.0     77.0
# ...                  ...                 ...            ...      ...      ...
# 5395           16.000000            1.000000       0.996004    775.0     58.0
# 5396           16.000000            1.000000       0.996004    786.0     48.0
# 5397           16.000000            1.000000       0.996004    726.0     46.0
# 5398           16.000000            1.000000       0.996004    646.0     48.0
# 5399           16.000016            1.002004       0.996000    860.0     64.0
#
#       ...  lbp_218  lbp_69  lbp_84  lbp_81  lbp_75   Contrast  Dissimilarity  \
# 0     ...     11.0     2.0     4.0     2.0     3.0  51.549031       2.291727
# 1     ...     16.0     3.0     3.0     5.0     6.0  58.574990       2.817129
# 2     ...     15.0     4.0     4.0     6.0     7.0  44.291367       2.332504
# 3     ...      7.0     NaN     1.0     3.0     7.0  35.597803       1.808868
# 4     ...      7.0     NaN     1.0     4.0     4.0  40.468257       1.879495
# ...   ...      ...     ...     ...     ...     ...        ...            ...
# 5395  ...     14.0     2.0     3.0     2.0     5.0  46.082826       2.291711
# 5396  ...      2.0     3.0     NaN     1.0     5.0  32.892402       1.785588
# 5397  ...      6.0     NaN     3.0     NaN     2.0  32.559220       1.791997
# 5398  ...      7.0     NaN     2.0     NaN     2.0  41.276217       2.076172
# 5399  ...      9.0     NaN     1.0     NaN     3.0  40.980802       2.032476
#
#       Homogeneity    Energy  Correlation
# 0        0.570736  0.106316     0.995416
# 1        0.528050  0.076842     0.994755
# 2        0.541551  0.070043     0.996042
# 3        0.615317  0.126540     0.996716
# 4        0.660526  0.141663     0.995904
# ...           ...       ...          ...
# 5395     0.632122  0.153362     0.995535
# 5396     0.701409  0.220911     0.996058
# 5397     0.689971  0.168319     0.996428
# 5398     0.664013  0.183470     0.995479
# 5399     0.644909  0.132125     0.995720
#
# [5400 rows x 269 columns]

# %%
os.listdir()
print(os.getcwd())
# Out:
# /Users/tony/Desktop/CoffeeBeansT

# %%
df.to_csv('feature_extractions_data.csv',index=False)
